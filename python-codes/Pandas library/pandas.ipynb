# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\rohit shrivastava\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\rohit shrivastava\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rohit shrivastava\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rohit shrivastava\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rohit shrivastava\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\rohit shrivastava\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
s=pd.Series([10,20,30,40,50])
print(s)
print(s.dtype)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# int64

# %%
l=[10,20,30,40]
s=pd.Series(l)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
l=[10,20,30,40]
s=pd.Series(l,index=["A","B","C","D"],name="python",dtype="float")
print(s)
# Out:
# A    10.0
# B    20.0
# C    30.0
# D    40.0
# Name: python, dtype: float64

# %%
d={"A":[10,20,30,40,50],"B":[100,200,300,400]}
s1=pd.Series(d)
print(s1)
print(type(s1))
print(s1["A"])
# Out:
# A    [10, 20, 30, 40, 50]
# B    [100, 200, 300, 400]
# dtype: object
# <class 'pandas.core.series.Series'>
# [10, 20, 30, 40, 50]

# %%
s=pd.Series(12,index=[1,2,3,4,5,6,7])
print(s)
# Out:
# 1    12
# 2    12
# 3    12
# 4    12
# 5    12
# 6    12
# 7    12
# dtype: int64

# %%
s1=pd.Series(12,index=[1,2,3,4,5,6,7])
s2=pd.Series(12,index=[1,2,3,4])
s3=s1+s2
print(s3)
# Out:
# 1    24.0
# 2    24.0
# 3    24.0
# 4    24.0
# 5     NaN
# 6     NaN
# 7     NaN
# dtype: float64

# %%
dic={"A":[10,20,30,40,50],"B":[100,200,300,400,500]}
df=pd.DataFrame(dic)
print(df)
print(type(df))
print(df["A"])
# Out:
#     A    B
# 0  10  100
# 1  20  200
# 2  30  300
# 3  40  400
# 4  50  500
# <class 'pandas.core.frame.DataFrame'>
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: A, dtype: int64

# %%
dic={"A":[10,20,30,40,50],"B":[100,200,300,400,500],1:[1000,2000,3000,4000,5000],
    "S":[1,2,3,4,5]}
df=pd.DataFrame(dic,columns=["A",1],index=["a","s","d","e","f"],dtype="float")
df
# Out:
#       A       1
# a  10.0  1000.0
# s  20.0  2000.0
# d  30.0  3000.0
# e  40.0  4000.0
# f  50.0  5000.0

# %%
l=[[10,20,30,40,50],[100,200,300,400,500]]
df=pd.DataFrame(l)
df
# Out:
#      0    1    2    3    4
# 0   10   20   30   40   50
# 1  100  200  300  400  500

# %%
d={"A":pd.Series([1,2,3,4]),"B":pd.Series([1,2,3,4])}
df=pd.DataFrame(d)
print(df)
print()
print(df["A"][2])
# Out:
#    A  B
# 0  1  1
# 1  2  2
# 2  3  3
# 3  4  4
#
# 3

# %%
# arithmetic
df=pd.DataFrame({"A":[10,20,30,40,50],"B":[1,2,3,4,5]})
df
# Out:
#     A  B
# 0  10  1
# 1  20  2
# 2  30  3
# 3  40  4
# 4  50  5

# %%
df["C"]=df["A"]+df["B"]
df
# Out:
#     A  B   C
# 0  10  1  11
# 1  20  2  22
# 2  30  3  33
# 3  40  4  44
# 4  50  5  55

# %%
df["C"]=df["A"]-df["B"]
df
# Out:
#     A  B   C
# 0  10  1   9
# 1  20  2  18
# 2  30  3  27
# 3  40  4  36
# 4  50  5  45

# %%
df["C"]=df["A"]*df["B"]
df
# Out:
#     A  B    C
# 0  10  1   10
# 1  20  2   40
# 2  30  3   90
# 3  40  4  160
# 4  50  5  250

# %%
df["C"]=df["A"]/df["B"]
df
# Out:
#     A  B     C
# 0  10  1  10.0
# 1  20  2  10.0
# 2  30  3  10.0
# 3  40  4  10.0
# 4  50  5  10.0

# %%
df["C"]=df["A"]%df["B"]
df
# Out:
#     A  B  C
# 0  10  1  0
# 1  20  2  0
# 2  30  3  0
# 3  40  4  0
# 4  50  5  0

# %%
df["C"]=df["A"]**df["B"]
df
# Out:
#     A  B          C
# 0  10  1         10
# 1  20  2        400
# 2  30  3      27000
# 3  40  4    2560000
# 4  50  5  312500000

# %%
df["python"]=df["A"]<=30
df["python_1"]=df["B"]>=3
df
# Out:
#     A  B          C  python  python_1
# 0  10  1         10    True     False
# 1  20  2        400    True     False
# 2  30  3      27000    True      True
# 3  40  4    2560000   False      True
# 4  50  5  312500000   False      True

# %%
df.insert(1,"python_2",df["A"])

# %%
df
# Out:
#     A  python_2  B
# 0  10        10  1
# 1  20        20  2
# 2  30        30  3
# 3  40        40  4
# 4  50        50  5

# %%
df.insert(2,"python_3",[10,20,30,40,50])
df
# Out:
#     A  B  python_3
# 0  10  1        10
# 1  20  2        20
# 2  30  3        30
# 3  40  4        40
# 4  50  5        50

# %%
py=df.pop("python_3")
py
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: python_3, dtype: int64

# %%
del df["python_3"]
df
# Out:
#     A  B
# 0  10  1
# 1  20  2
# 2  30  3
# 3  40  4
# 4  50  5

# %%
df=pd.DataFrame({"A":[10,20,30,40,50],"B":[1,2,3,4,5]})
df
# Out:
#     A  B
# 0  10  1
# 1  20  2
# 2  30  3
# 3  40  4
# 4  50  5

# %%
# read csv
df=pd.read_csv(r"C:\Users\Rohit shrivastava\Downloads\previous_application.csv")
df
# Out:
#        SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 0         2030495      271877     Consumer loans     1730.430
# 1         2802425      108129         Cash loans    25188.615
# 2         2523466      122040         Cash loans    15060.735
# 3         2819243      176158         Cash loans    47041.335
# 4         1784265      202054         Cash loans    31924.395
# ...           ...         ...                ...          ...
# 49994     1171956      339569         Cash loans          NaN
# 49995     1904808      363980         Cash loans          NaN
# 49996     2331005      231295         Cash loans    22176.405
# 49997     1960897      346691         Cash loans          NaN
# 49998     1979352      363244         Cash loans    24909.390
#
#        AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 0              17145.0     17145.0               0.0          17145.0
# 1             607500.0    679671.0               NaN         607500.0
# 2             112500.0    136444.5               NaN         112500.0
# 3             450000.0    470790.0               NaN         450000.0
# 4             337500.0    404055.0               NaN         337500.0
# ...                ...         ...               ...              ...
# 49994              0.0         0.0               NaN              NaN
# 49995              0.0         0.0               NaN              NaN
# 49996         180000.0    216418.5               NaN         180000.0
# 49997              0.0         0.0               NaN              NaN
# 49998         360000.0    409896.0               NaN         360000.0
#
#       WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  ...  \
# 0                       SATURDAY                       15  ...
# 1                       THURSDAY                       11  ...
# 2                        TUESDAY                       11  ...
# 3                         MONDAY                        7  ...
# 4                       THURSDAY                        9  ...
# ...                          ...                      ...  ...
# 49994                   THURSDAY                       11  ...
# 49995                     FRIDAY                       10  ...
# 49996                    TUESDAY                       12  ...
# 49997                  WEDNESDAY                       16  ...
# 49998                     FRIDAY                       18  ...
#
#       NAME_SELLER_INDUSTRY  CNT_PAYMENT  NAME_YIELD_GROUP  \
# 0             Connectivity         12.0            middle
# 1                      XNA         36.0        low_action
# 2                      XNA         12.0              high
# 3                      XNA         12.0            middle
# 4                      XNA         24.0              high
# ...                    ...          ...               ...
# 49994                  XNA          NaN               XNA
# 49995                  XNA          NaN               XNA
# 49996                  XNA         12.0            middle
# 49997                  XNA          NaN               XNA
# 49998                  XNA         36.0              high
#
#             PRODUCT_COMBINATION  DAYS_FIRST_DRAWING DAYS_FIRST_DUE  \
# 0      POS mobile with interest            365243.0          -42.0
# 1              Cash X-Sell: low            365243.0         -134.0
# 2             Cash X-Sell: high            365243.0         -271.0
# 3           Cash X-Sell: middle            365243.0         -482.0
# 4             Cash Street: high                 NaN            NaN
# ...                         ...                 ...            ...
# 49994                      Cash                 NaN            NaN
# 49995                      Cash                 NaN            NaN
# 49996       Cash X-Sell: middle            365243.0         -670.0
# 49997                      Cash                 NaN            NaN
# 49998         Cash X-Sell: high                 NaN            NaN
#
#       DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE DAYS_TERMINATION  \
# 0                         300.0          -42.0            -37.0
# 1                         916.0       365243.0         365243.0
# 2                          59.0       365243.0         365243.0
# 3                        -152.0         -182.0           -177.0
# 4                           NaN            NaN              NaN
# ...                         ...            ...              ...
# 49994                       NaN            NaN              NaN
# 49995                       NaN            NaN              NaN
# 49996                    -340.0         -340.0           -338.0
# 49997                       NaN            NaN              NaN
# 49998                       NaN            NaN              NaN
#
#       NFLAG_INSURED_ON_APPROVAL
# 0                           0.0
# 1                           1.0
# 2                           1.0
# 3                           1.0
# 4                           NaN
# ...                         ...
# 49994                       NaN
# 49995                       NaN
# 49996                       1.0
# 49997                       NaN
# 49998                       NaN
#
# [49999 rows x 37 columns]

# %%
df=pd.DataFrame({"A":[10,20,30,40,50],"B":[1,2,3,4,5]})
df
# Out:
#     A  B
# 0  10  1
# 1  20  2
# 2  30  3
# 3  40  4
# 4  50  5

# %%
# write csv
df.to_csv(r"C:\Users\Rohit shrivastava\Desktop\newfile.csv",index=False)
df
# Out:
#     A    B
# 0  10  100
# 1  20  200
# 2  30  300
# 3  40  400
# 4  50  500

# %%
d={"A":pd.Series([1,2,3,4]),"B":pd.Series([1,2,3,4])}
df1=pd.DataFrame(d)
df1
# Out:
#    A  B
# 0  1  1
# 1  2  2
# 2  3  3
# 3  4  4
