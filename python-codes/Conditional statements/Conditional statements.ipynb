# %%
a=input("enter any number: ")  # input function takes input as string .
b=input("enter any number: ") #  For changing data type we use typecasting
c=a+b
print(c)
# Out:
# enter any number:  1
# enter any number:  2
# 12

# %% [markdown]
# # typecasting

# %%
# typecasting
a=int(input("enter 1st number: "))
b=int(input("enter 2nd number: "))
c=a+b
print("sum is ",c)
# Out:
# enter 1st number:  1
# enter 2nd number:  2
# sum is  3

# %% [markdown]
# # control flow statement

# %%
# control flow statement
# conditional statement
#if 
num=10
if num%2==0:
    print(num,"is an even number")
# Out:
# 10 is an even number

# %%
#if else
num=int(input("enter any number: "))
if num%2==0:
    print(num,"is an even number")
else:
    print(num,"is an odd number")
# Out:
# enter any number:  1
# 1 is an odd number

# %%
#wap to check whether a user is eligible to vote or not
age=int(input("enter your age: "))
if age>=18:
    print("you are eligible to vote")
else:
    print("you are not eligible to vote")
# Out:
# enter your age:  19
# you are eligible to vote

# %%
# wap to check whether a number is divisible by 3 or not
num=int(input("enter any number: "))
if num%3==0:
    print(num,"is divisible by 3")
else:
    print(num,"is not divisible by 3")
# Out:
# enter any number:  11
# 11 is not divisible by 3

# %%
# wap to check whether the last digit of any number is divisible by 3 or not
num=int(input("enter any number :"))
a=num%10
if a%3==0:
    print("unit digit is divisible by 3")
else:
    print("unit digit is not divisible by 3")
# Out:
# enter any number : 10
# unit digit is divisible by 3

# %%
science=int(input("enter marks in science :"))
lang=int(input("enter markse in language :"))
maths=int(input("enter marks in maths :"))
obtained_marks=science+lang+maths
per=(obtained_marks/300)*100
print("obtained marks :",obtained_marks)
print("percentage :",per)
if per>=65:
    print("1st division ")
elif per>=50:
    print("2nd division ")
elif per>=33:
    print("3rd division ")
else:
    print("fail")
# Out:
# enter marks in science : 34
# enter markse in language : 54
# enter marks in maths : 76
# obtained marks : 164
# percentage : 54.666666666666664
# 2nd division

# %%
a=int(input("enter a number"))
if a>0:
      if a%2==0:
         print("positive even number ")
      else:
          print("positive odd number")
elif a==0:
    print("number is zero")
else:
    print("number is negative")
# Out:
# enter a number 2
# positive even number

# %%
a1=int(input("enter length of 1st side"))
a2=int(input("enter length of 2nd side"))
a3=int(input("enter length of 3rd side"))
if a1!=0 and a2!=0 and a3!=0:
    if  a1+a2>a3 and  a1+a3>a2 and a2+a3>a1:
        if a1==a2 and a1==a3:
            print("equilateral triangle ")
        elif a1==a2 or a2==a3:
            print("isosceles triangle ")
        else:
            print("scalene triangle ")
    else:
        print("values incorrect")
else:
    print("invalid input")

# %%
ta=int(input("enter account balance"))
wa=int(input("enter withdrawal amount"))
if ta>=wa:
    cb=ta-wa
    print("balance after withdrawal",cb)
else:
    print(ta,"insufficient balance")
# Out:
# enter account balance 12
# enter withdrawal amount 13
# 12 insufficient balance

# %%
year=int(input("enter any year"))
if year%4==0:
    if year%100==0:
        if year%400==0:
            print(year,"century leap year")
        else:
            print(year,"century not a leap year")
    else:
        print(year,"non century leap year")
else:
    print(year,"non century not a leap year")
# Out:
# enter any year 1213
# 1213 non century not a leap year

# %%
year=int(input("enter any year"))
if year%4==0 and year%100!=0 or year%400==0:
    print(year,"leap year")
else:
    print(year,"not a leap year")
# Out:
# enter any year 1312
# 1312 leap year

# %% [markdown]
# ## Logical operators in conditionals

# %%
x = 7
if x > 5 and x < 10:
    print("x is between 5 and 10")

if x < 5 or x > 10:
    print("x is outside the range 5-10")

if not (x == 7):
    print("x is not equal to 7")
# Out:
# x is between 5 and 10

# %%
x = 10
result = "Even" if x % 2 == 0 else "Odd"
print(result)
# Out:
# Even
