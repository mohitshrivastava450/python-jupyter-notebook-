# %% [markdown]
# # String

# %% [markdown]
# ## Indexing and slicing

# %%
# indexing - position ---- access character from given string
s="welcome to bhopal"
print(s[1])
#slicing - extract substring from given string
# strobj[start:stop:step]
# start - 0
# STOP - end of the string - given condition -- n-1
# step - +1
# slicing
print(s[::-1])  #reverse string
print(s[1::3])
print(s[-1::-2])
print(s[1:6:2])
print(s[0:7:])
print(s[-1:-14:-2])
# Out:
# e
# lapohb ot emoclew
# eo  ol
# lph teolw
# ecm
# welcome
# lph teo

# %% [markdown]
# ## Iteration

# %%
# iteration
# direct iteration
s="decode"
for i in s:
    print(i)
# Out:
# d
# e
# c
# o
# d
# e

# %%
# indirect iteration
s="decode"
for i in range(len(s)):
    print(i,s[i])
# Out:
# 0 d
# 1 e
# 2 c
# 3 o
# 4 d
# 5 e

# %%
# program to print reverse of any given string
s=input("enter any string : ")
rev=""
for i in s:
    rev=i+rev
print(rev)       #with direct iteration
print(s[::-1])   #with slicing
# Out:
# enter any string :  decode
# edoced
# edoced

# %%
# program to check whether a given is palindrome or not
s=input("enter any string : ")
rev=""
for i in s:
    rev=i+rev
    #sprint(rev)
if rev==s:
    print(rev,"given string is palindrome")
else:
    print(rev,"given string is not palindrome")
# Out:
# enter any string :  naman
# n
# an
# man
# aman
# naman
# naman given string is palindrome

# %%
s=input("enter any string : ")
if s==s[::-1]:
    print(s,"given string is palindrome")
else:
    print(s,"given string is not palindrome")
# Out:
# enter any string :  wert
# wert given string is not palindrome

# %%
# counting
#len()
# return number of characters in a given string
# len(strobj)
s="decode"
print(len(s))
count=0
for i in s:
    count=count+1
print(count)
# Out:
# 6
# 6

# %%
# chr(number) - take ascii value as a parameter and return character
num1=66
print(chr(num1))
print(chr(97))
print(chr(98))
print(chr(345))
# Out:
# B
# a
# b
# ř

# %%
# ord(character) - take character as an input and return ascii value
print(ord("a"))
print(ord("/"))
print(ord("A"))
print(ord("@"))
# Out:
# 97
# 47
# 65
# 64

# %%
#max()
#min()
s="decode"
print(max(s))
print(min(s))
# Out:
# o
# c

# %%
#max_value
s="decode"
max_value=s[0]
for i in s:
    if i>max_value:
        max_value=i
print(max_value)
# Out:
# o

# %%
#min_value
s="decode"
min_value=s[0]
for i in s:
    if i<min_value:
        min_value=i
print(min_value)
# Out:
# c

# %%
s1="welcome to city of lakes"
v=0
c=0
s=0
for i in s1:
    if i in "aeiouAEIOU":
        v=v+1
    elif i==" ":
        s=s+1
    else:
        c=c+1
print("vowels :",v)
print("consonants :",c)
print("spaces :",s)
# Out:
# vowels : 8
# consonants : 12
# spaces : 4

# %% [markdown]
# ## String Methods

# %%
# upper() - strobj.upper()
# lower() - strobj.lower()
# title() - strobj.title()
# capitalize() - strobj.capitalize()
s="welcome to bhopal"
print(s.upper())
print(s.lower())
print(s.title())
print(s.capitalize())
# Out:
# WELCOME TO BHOPAL
# welcome to bhopal
# Welcome To Bhopal
# Welcome to bhopal

# %%
# isalpha()
# strobj.isalpha()
s="decode"
s1="decode1"
print(s.isalpha())
print(s1.isalpha())
# Out:
# True
# False

# %%
# isdigit
# strobj.isdigit()
s="1234"
s1="decode1234"
print(s.isdigit())
print(s1.isdigit())
# Out:
# True
# False

# %%
# isalnum()
# strobj.isalnum()
s1="decode1234"
print(s1.isalnum())
# Out:
# True

# %% [markdown]
# ## Alphabet Patterns

# %%
n=5
for i in range(n):
    for j in range(i+1):
        print(chr(65+j),end=" ")
    print()
# Out:
# A
# A B
# A B C
# A B C D
# A B C D E

# %%
# islower()
# isupper()
s="decode"
print(s.isupper())
print(s.islower())
# Out:
# False
# True

# %%
n=5
for i in range(n):
    for j in range(n-i):
        print(" ",end=" ")
    for k in range(i+1):
        print(chr(65+i),end=" ")
    for l in range(k):
        print(chr(65+k),end=" ")
    print()
# Out:
#           A
#         B B B
#       C C C C C
#     D D D D D D D
#   E E E E E E E E E

# %%
n=5
for i in range(n):
    for j in range(n-i):
        print(" ",end=" ")
    for j in range(i):
        print(chr(65+j),end=" ")
    for j in range(i+1):
        print(chr(65+j),end=" ")
    print()
# Out:
#           A
#         A A B
#       A B A B C
#     A B C A B C D
#   A B C D A B C D E

# %%
n=5
for i in range(n):
    for j in range(n-i):
        print(" ",end=" ")
    for k in range(i+1):
        print(chr(65+k),end=" ")
    for l in range(k):
        print(chr(65+l),end=" ")
    print()
# Out:
#           A
#         A B A
#       A B C A B
#     A B C D A B C
#   A B C D E A B C D

# %%
n=5
for i in range(n):
    for j in range(n-i-1):
        print(" ",end=" ")
    for j in range(i+1):
        print(chr(65+i),end=" ")
    print()
# Out:
#         A
#       B B
#     C C C
#   D D D D
# E E E E E

# %%
n=5
for i in range(n):
    for j in range(n-i-1):
        print(" ",end=" ")
    for j in range(i+1):
        print(chr(65+j),end=" ")
    print()
# Out:
#         A
#       A B
#     A B C
#   A B C D
# A B C D E

# %%
n=5
for i in range(n):
    for j in range(i+1):
        print(chr(65+i-j),end=" ")
    print()
# Out:
# A
# B A
# C B A
# D C B A
# E D C B A

# %%
# count() - return occurence of particular character/substring in a given string
# strobj.count(string/character,[start],[stop])
s="welcome to bhopal"
print(s.count("o"))
print(s.count("o",5))
print(s.count("o",5,10))
print(s.count("o",5,9))
print(s.count("decode"))
print(s.count("bhopal"))
# Out:
# 3
# 2
# 1
# 0
# 0
# 1

# %%
# strip()
# strobj.strip(string)
s="...?#rrrdecodett,,$,,/"
print(s.strip(".?#rt,$/"))
# Out:
# decode

# %%
# index() - return position
# strobj.index(char/substring,[start],[stop])
# index error- if data not found
s="welcome to bhopal"
print(s.index("o"))
print(s.index("o",5))
print(s.index("bhopal"))
print(s.index("o",5,9))
# Out:
# 4
# 9
# 11
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 7
#       5 print(s.index("o",5))
#       6 print(s.index("bhopal"))
# ----> 7 print(s.index("o",5,9))
#
# ValueError: substring not found

# %%
# find() - return position
# strobj.index(char/substring,[start],[stop])
# find - does not give error if data not found
s="welcome to bhopal"
print(s.find("o"))
print(s.find("o",5))
print(s.find("bhopal"))
print(s.find("o",5,9))
# Out:
# 4
# 9
# 11
# -1

# %%
# replace
# strobj.replace(oldstring,newstring,[count])
s="welcome to bhopal"
print(s.replace("bhopal","decode"))
print(s.replace("o","a"))
# Out:
# welcome to decode
# welcame ta bhapal

# %%
# split()
# strobj.split([seperator],[maxsplit])
# by default - whitespace , maxsplit= max no of seperator
# split always return list of strings.
s="welcome to city of lakes"
print(s.split())
print(s.split(" ",1))
print(s.split(" "))
# Out:
# ['welcome', 'to', 'city', 'of', 'lakes']
# ['welcome', 'to city of lakes']
# ['welcome', 'to', 'city', 'of', 'lakes']

# %%
s="welcome,to,city of lakes"
print(s.split(","))
# Out:
# ['welcome', 'to', 'city of lakes']

# %%
# join 
# seperator.join(s)
s=["welcome","to","bhopal"]
s1=" ".join(s)
print(s1)
# Out:
# welcome to bhopal

# %%
s="hello"
s1="-".join(s)
print(s1)
s2=s1.split("-")
print(s2)
s3="".join(s2)
print(s3)
# Out:
# h-e-l-l-o
# ['h', 'e', 'l', 'l', 'o']
# hello
